# %%
from llama_index.readers.web import SimpleWebPageReader
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from llama_index.readers.web import SimpleWebPageReader
#
# File g:\PineconeUtils\venv\lib\site-packages\llama_index\readers\web\__init__.py:2
#       1 """Init file."""
# ----> 2 from llama_index.readers.web.async_web.base import (
#       3     AsyncWebPageReader,
#       4 )
#       5 from llama_index.readers.web.beautiful_soup_web.base import (
#       6     BeautifulSoupWebReader,
#       7 )
#       8 from llama_index.readers.web.browserbase_web.base import BrowserbaseWebReader
#
# File g:\PineconeUtils\venv\lib\site-packages\llama_index\readers\web\async_web\base.py:5
#       2 import logging
#       3 from typing import List
# ----> 5 from llama_index.core.readers.base import BaseReader
#       6 from llama_index.core.schema import Document
#       8 logger = logging.getLogger(__name__)
#
# ...
